# %%
import pandas as pd
import numpy as np
import random, re
from scipy.stats import norm
import matplotlib.pyplot as plt

# %%
# load a text version of the kenpom data and creat a dictionary
def loadkp(fname):
    keys = 'Rank        Team    Conf    W-L     AdjEM   AdjO    AdjD    AdjT    Luck    SOSAdjEM        SOSOppO SOSOppD NCSOSAdjEM'.split()
    f = open(fname).readlines()
    kpd = {}
    for line in f:
        lsp = line.split('\t')
        if 'Strength' in lsp[0] or 'Rank' in lsp[0]: pass
        else:
            datanorank =  [lsp[i] for i in [0,1,2,3,4,5,7,9,11,13,15,17,19]]
            datanorank[1] = re.split('(\d+)',datanorank[1])[0].strip()
            teamd = dict(zip(keys,datanorank))
            if len(re.split('(\d+)',lsp[1])) > 1:
                ncaaseed = re.split('(\d+)',lsp[1])[1].strip()
                teamd['ncaaseed'] = ncaaseed
            kpd[datanorank[1]] = teamd
    return kpd

# function to calculate kenpom probabilities. a is away team, b is home team. 
def kpprob(a,b,kpd,std=7,homea=0):
    adjemdiff = ((float(kpd[a]['AdjEM']) - float(kpd[b]['AdjEM']))*
                (float(kpd[a]['AdjT']) + float(kpd[b]['AdjT']))/200.0) - homea
    bprob = norm.cdf(0,adjemdiff,std)
    aprob = 1.0-bprob
    return aprob,bprob,adjemdiff

# pick a winner base on the above kenpom probability fucntion
def pickw(pfunc,kpd,g,**kwargs):
    if random.random() <= pfunc(g[0].strip(),g[1].strip(),kpd,**kwargs)[0]: return g[0].strip()
    else: return g[1].strip()

# %%
years = [str(val).zfill(2) for val in range(2,19)]
fullresd = {}
allkp = {}
for year in years:
    print year
    kpd = loadkp('kp{0}.txt'.format(year))
    allkp['20'+year] = kpd
    resd = pd.read_csv('b10_{0}.csv'.format(year))

    awayt = resd['Visitor/Neutral'].values
    homet = resd['Home/Neutral'].values
    pdiff = resd['PTS'] - resd['PTS.1']
    resd['PD.act'] = pdiff

    expdiffs = [kpprob(v[0],v[1],kpd,std=11,homea=0)[2] for v in zip(awayt,homet)]
    resd['PD.exp'] = expdiffs

    resd['PD.ha'] = resd['PD.act'] - resd['PD.exp']

    teams = list(set(list(homet)))
#     for team in sorted(teams):
#         print team, resd.loc[resd['Home/Neutral'] == team, 'PD.ha'].mean()
        
    fullresd['20'+year] = resd
# Out:
# 02
# 03
# 04
# 05
# 06
# 07
# 08
# 09
# 10
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18

# %%
fullresd['2018']
# Out:
#                 Date Visitor/Neutral  PTS  Home/Neutral  PTS.1   OT  Notes  \
# 0     Fri Dec 1 2017          Purdue   80      Maryland     75  NaN    NaN
# 1     Fri Dec 1 2017        Illinois   68  Northwestern     72   OT    NaN
# 2     Sat Dec 2 2017        Penn St.   77          Iowa     73  NaN    NaN
# 3     Sat Dec 2 2017         Indiana   55      Michigan     69  NaN    NaN
# 4     Sat Dec 2 2017        Ohio St.   83     Wisconsin     58  NaN    NaN
# 5     Sun Dec 3 2017        Maryland   92      Illinois     91   OT    NaN
# 6     Sun Dec 3 2017        Nebraska   57  Michigan St.     86  NaN    NaN
# 7     Sun Dec 3 2017         Rutgers   67     Minnesota     89  NaN    NaN
# 8     Sun Dec 3 2017    Northwestern   69        Purdue     74  NaN    NaN
# 9     Mon Dec 4 2017            Iowa   64       Indiana     77  NaN    NaN
# 10    Mon Dec 4 2017        Michigan   62      Ohio St.     71  NaN    NaN
# 11    Mon Dec 4 2017       Wisconsin   64      Penn St.     63  NaN    NaN
# 12    Tue Dec 5 2017       Minnesota   68      Nebraska     78  NaN    NaN
# 13    Tue Dec 5 2017    Michigan St.   62       Rutgers     52  NaN    NaN
# 14    Tue Jan 2 2018        Michigan   75          Iowa     68  NaN    NaN
# 15    Tue Jan 2 2018        Penn St.   69      Maryland     75  NaN    NaN
# 16    Tue Jan 2 2018        Nebraska   70  Northwestern     55  NaN    NaN
# 17    Tue Jan 2 2018         Indiana   61     Wisconsin     71  NaN    NaN
# 18    Wed Jan 3 2018        Illinois   67     Minnesota     77  NaN    NaN
# 19    Wed Jan 3 2018         Rutgers   51        Purdue     82  NaN    NaN
# 20    Thu Jan 4 2018        Ohio St.   92          Iowa     81  NaN    NaN
# 21    Thu Jan 4 2018        Maryland   61  Michigan St.     91  NaN    NaN
# 22    Fri Jan 5 2018    Northwestern   63      Penn St.     78  NaN    NaN
# 23    Fri Jan 5 2018       Wisconsin   60       Rutgers     64  NaN    NaN
# 24    Sat Jan 6 2018        Illinois   69      Michigan     79  NaN    NaN
# 25    Sat Jan 6 2018         Indiana   75     Minnesota     71  NaN    NaN
# 26    Sat Jan 6 2018        Nebraska   62        Purdue     74  NaN    NaN
# 27    Sun Jan 7 2018            Iowa   73      Maryland     91  NaN    NaN
# 28    Sun Jan 7 2018    Michigan St.   64      Ohio St.     80  NaN    NaN
# 29    Tue Jan 9 2018        Penn St.   70       Indiana     74  NaN    NaN
# ..               ...             ...  ...           ...    ...  ...    ...
# 96   Sun Feb 11 2018        Michigan   83     Wisconsin     72  NaN    NaN
# 97   Tue Feb 13 2018    Michigan St.   87     Minnesota     57  NaN    NaN
# 98   Tue Feb 13 2018        Maryland   66      Nebraska     70  NaN    NaN
# 99   Tue Feb 13 2018    Northwestern   58       Rutgers     67   OT    NaN
# 100  Wed Feb 14 2018        Illinois   68       Indiana     78  NaN    NaN
# 101  Wed Feb 14 2018            Iowa   59      Michigan     74  NaN    NaN
# 102  Thu Feb 15 2018        Ohio St.   56      Penn St.     79  NaN    NaN
# 103  Thu Feb 15 2018          Purdue   53     Wisconsin     57  NaN    NaN
# 104  Sat Feb 17 2018         Indiana   84          Iowa     82  NaN    NaN
# 105  Sat Feb 17 2018         Rutgers   51      Maryland     61  NaN    NaN
# 106  Sat Feb 17 2018    Michigan St.   65  Northwestern     60  NaN    NaN
# 107  Sun Feb 18 2018        Nebraska   66      Illinois     72  NaN    NaN
# 108  Sun Feb 18 2018        Ohio St.   62      Michigan     74  NaN    NaN
# 109  Sun Feb 18 2018        Penn St.   73        Purdue     76  NaN    NaN
# 110  Mon Feb 19 2018        Maryland   71  Northwestern     64  NaN    NaN
# 111  Mon Feb 19 2018       Minnesota   63     Wisconsin     73   OT    NaN
# 112  Tue Feb 20 2018        Illinois   61  Michigan St.     81  NaN    NaN
# 113  Tue Feb 20 2018         Indiana   57      Nebraska     66  NaN    NaN
# 114  Tue Feb 20 2018         Rutgers   52      Ohio St.     79  NaN    NaN
# 115  Wed Feb 21 2018            Iowa   82     Minnesota     86  NaN    NaN
# 116  Wed Feb 21 2018        Michigan   72      Penn St.     63  NaN    NaN
# 117  Thu Feb 22 2018          Purdue   93      Illinois     86  NaN    NaN
# 118  Thu Feb 22 2018       Wisconsin   70  Northwestern     64  NaN    NaN
# 119  Fri Feb 23 2018        Ohio St.   80       Indiana     78  2OT    NaN
# 120  Sat Feb 24 2018        Michigan   85      Maryland     61  NaN    NaN
# 121  Sun Feb 25 2018    Northwestern   70          Iowa     77  NaN    NaN
# 122  Sun Feb 25 2018        Penn St.   64      Nebraska     76  NaN    NaN
# 123  Sun Feb 25 2018       Minnesota   60        Purdue     84  NaN    NaN
# 124  Sun Feb 25 2018        Illinois   75       Rutgers     62  NaN    NaN
# 125  Sun Feb 25 2018    Michigan St.   68     Wisconsin     63  NaN    NaN
#
#      PD.act     PD.exp      PD.ha
# 0         5   7.502700  -2.502700
# 1        -4  -1.271100  -2.728900
# 2         4   7.595520  -3.595520
# 3       -14  -9.047200  -4.952800
# 4        25   6.796280  18.203720
# 5         1   5.693160  -4.693160
# 6       -29  -7.976640 -21.023360
# 7       -22  -1.364790 -20.635210
# 8        -5 -11.602350   6.602350
# 9       -13  -1.574350 -11.425650
# 10       -9   2.004880 -11.004880
# 11        1  -5.525000   6.525000
# 12      -10  -5.803560  -4.196440
# 13       10  14.856100  -4.856100
# 14        7  10.856560  -3.856560
# 15       -6   2.772200  -8.772200
# 16       15   3.262805  11.737195
# 17      -10  -0.155160  -9.844840
# 18      -10   1.110615 -11.110615
# 19      -31 -15.451200 -15.548800
# 20       11   8.938230   2.061770
# 21      -30  -6.918270 -23.081730
# 22      -15  -6.960160  -8.039840
# 23       -4   4.897035  -8.897035
# 24      -10 -11.815220   1.815220
# 25        4   3.655520   0.344480
# 26      -12  -8.567290  -3.432710
# 27      -18  -4.705870 -13.294130
# 28      -16   2.847500 -18.847500
# 29       -4   5.851430  -9.851430
# ..      ...        ...        ...
# 96       11   8.625760   2.374240
# 97       30  13.905720  16.094280
# 98       -4   0.996065  -4.996065
# 99       -9   3.572250 -12.572250
# 100     -10  -2.573025  -7.426975
# 101     -15 -10.856560  -4.143440
# 102     -23   1.329570 -24.329570
# 103      -4  10.125705 -14.125705
# 104       2   1.574350   0.425650
# 105     -10  -7.911540  -2.088460
# 106       5  11.021780  -6.021780
# 107      -6   4.716255 -10.716255
# 108     -12  -2.004880  -9.995120
# 109      -3  -4.768025   1.768025
# 110       7   4.205460   2.794540
# 111     -10  -3.710000  -6.290000
# 112     -20 -12.827530  -7.172470
# 113      -9  -2.077000  -6.923000
# 114     -27 -12.029850 -14.970150
# 115      -4   2.143530  -6.143530
# 116       9   3.318220   5.681780
# 117       7  13.435800  -6.435800
# 118       6   1.335630   4.664370
# 119       2   7.160960  -5.160960
# 120      24   6.015520  17.984480
# 121      -7   0.288530  -7.288530
# 122     -12   3.798540 -15.798540
# 123     -24 -14.515150  -9.484850
# 124      13   2.446200  10.553800
# 125       5   9.552405  -4.552405
#
# [126 rows x 10 columns]

# %%
pan = pd.Panel(fullresd)

# %%
pan['2002']['PD.ha'].dropna().mean()
# Out:
# -6.8497302840909127

# %%
years = range(2002,2018)
stds = []
for year in years:
    std = pan[str(year)]['PD.exp'].std()
    stds.append(std)
    
print np.array(std).mean()
# Out:
# 6.16020548983

# %%
years = range(2002,2018)
for team in teams:
    ranks, homeas = [], []
    for year in years:
        stryear = str(year)
        homea_yr = pan[stryear].loc[pan[stryear]['Home/Neutral'] == team, 'PD.ha'].mean()
        rank = allkp[stryear][team]['Rank']
        ranks.append(rank)
        homeas.append(homea_yr)

    print team, np.nanmean(np.array(homeas))
# Out:
# Northwestern -3.30489294271
# Penn St. -3.69490145399
# Wisconsin -5.1313155599
# Ohio St. -4.64177692708
# Michigan St. -5.38495300781
# Michigan -4.15913175781
# Purdue -6.07407303385
# Minnesota -4.33457042101
# Illinois -4.08198338542
# Rutgers -0.453445925926
# Nebraska -4.39356787037
# Indiana -5.09584558594
# Iowa -5.30968264757
# Maryland -3.50976111111

# %%
print homeas
# print np.array(homeas).mean()
# print np.array(homeas).std()
# Out:
# [True, True, True, True, True, True, True, True, True, True, True, True, True, -4.744759444444444, -4.983985, -0.8005388888888897]
